# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Salary_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
X = df[['YearsExperience']]
X.head()
# Out:
#    YearsExperience
# 0              1.2
# 1              1.4
# 2              1.6
# 3              2.1
# 4              2.3

# %%
Y = df[['Salary']]
Y.head()
# Out:
#     Salary
# 0  39344.0
# 1  46206.0
# 2  37732.0
# 3  43526.0
# 4  39892.0

# %%
plt.scatter(X, Y,marker='+')
plt.xlabel('Years of experience -->')
plt.ylabel('Salary-->')
plt.title('XYZ Company')
# Out:
# Text(0.5, 1.0, 'XYZ Company')

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_test
# Out:
#       Salary
# 22  101303.0
# 15   67939.0
# 24  109432.0
# 2    37732.0
# 9    57190.0
# 11   55795.0

# %%
plt.scatter(X, Y,marker='+')
plt.plot(x_test, model.predict(x_test),color='red')
plt.xlabel('Years of experience -->')
plt.ylabel('Salary-->')
plt.title('XYZ Company')
# Out:
# Text(0.5, 1.0, 'XYZ Company')

# %%
model = LinearRegression()

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.predict([[3]])
# Out:
# C:\Users\chaks\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[53198.09093089]])

# %%
model.coef_
# Out:
# array([[9449.96232146]])

# %%
model.intercept_
# Out:
# array([24848.20396652])

# %%
import pickle

# %%
with open('pickle_model','wb') as f:
    pickle.dump(model,f)

# %%
with open('pickle_model','rb') as f  :
    mp = pickle.load(f)

# %%
mp.predict([[5]])
# Out:
# C:\Users\chaks\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[72098.0155738]])

# %%
# using joblib 
import joblib

# %%
joblib.dump(model,'joblib_model')
# Out:
# ['joblib_model']

# %%
jm = joblib.load('joblib_model')

# %%
jm.predict([[5]])
# Out:
# C:\Users\chaks\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[72098.0155738]])
